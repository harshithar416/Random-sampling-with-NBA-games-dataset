# %% [markdown]
# #                                            NBA Games Dataset

# %% [markdown]
# #### Description :   This dataset is collected from the NBA stats website. The inspiration to pick dataset is not only because of my hobbie to play basketball but also NBA is one of the highest paid and viewed sport in the United States. In this dataset we are going to pick one of the coulmn (PT_home) and perform our required sampling. By end of this visualization we will be able to find the various mean,median , mode and standard deviation of the points coulmn but we are also going to look into the various random sampling and draw inference from them.

# %% [markdown]
# ##### Cloumn description (for first 10):
# ##### GAME_DATE_EST : Game's date
# ##### GAME_ID : ID of the game
# ##### GAME_STATUS_TEXT : Status : Final means that the is completed
# ##### HOME_TEAM_ID : ID of the home team
# ##### VISITOR_TEAM_ID : ID of the visitor team
# ##### SEASON : Season when the game occured
# ##### TEAM_ID_home : ID of the home team (dupplicate of HOME_TEAM_ID)
# #### PTS_home : Number of points scored by home team
# ##### FG_PCT_home : Field Goal Percentage home team
# ##### FT_PCT_home : Free Throw Percentage of the home team

# %%
#Importing libraries 
import numpy as np 
import pandas as pd

# %%
#Reading the game file 
game_df = pd.read_csv("games.csv")

# %%
game_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    26-05-2021  42000102            Final    1610612755       1610612764
# 1    26-05-2021  42000132            Final    1610612752       1610612737
# 2    26-05-2021  42000142            Final    1610612762       1610612763
# 3    25-05-2021  42000112            Final    1610612751       1610612738
# 4    25-05-2021  42000152            Final    1610612756       1610612747
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2020    1610612755     120.0        0.557        0.684  ...      26.0
# 1    2020    1610612752     101.0        0.383        0.739  ...      15.0
# 2    2020    1610612762     141.0        0.544        0.774  ...      28.0
# 3    2020    1610612751     130.0        0.523        0.955  ...      31.0
# 4    2020    1610612756     102.0        0.465        0.933  ...      21.0
#
# ...

# %%
game_df.tail()
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 24672    06-10-2014  11400007            Final    1610612737       1610612740
# 24673    06-10-2014  11400004            Final    1610612741       1610612764
# 24674    06-10-2014  11400005            Final    1610612747       1610612743
# 24675    05-10-2014  11400002            Final    1610612761       1610612758
# 24676    04-10-2014  11400001            Final    1610612748       1610612740
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 24672    2014    1610612737      93.0        0.419        0.821  ...
# 24673    2014    1610612741      81.0        0.338        0.719  ...
# 24674    2014    1610612747      98.0        0.448        0.682  ...
# 24675    2014    1610612761      99.0        0.440        0.771  ...
# 24676    2014    1610612748      86.0        0.431        0.679  ...
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# ...

# %%
game_df.dtypes
# Out:
# GAME_DATE_EST        object
# GAME_ID               int64
# GAME_STATUS_TEXT     object
# HOME_TEAM_ID          int64
# VISITOR_TEAM_ID       int64
# SEASON                int64
# TEAM_ID_home          int64
# PTS_home            float64
# FG_PCT_home         float64
# FT_PCT_home         float64
# FG3_PCT_home        float64
# AST_home            float64
# REB_home            float64
# TEAM_ID_away          int64
# PTS_away            float64
# FG_PCT_away         float64
# FT_PCT_away         float64
# FG3_PCT_away        float64
# AST_away            float64
# REB_away            float64
# HOME_TEAM_WINS        int64
# dtype: object

# %%
#Finding the mean and std deviation of the PTS_home
game_df.PTS_home.describe()
# Out:
# count    24578.000000
# mean       102.766621
# std         13.112642
# min         36.000000
# 25%         94.000000
# 50%        102.000000
# 75%        111.000000
# max        168.000000
# Name: PTS_home, dtype: float64

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')

print("The shape of the dataframe is: ", game_df.shape)
plt.figure(figsize=(6,4))
sns.boxplot(game_df['PTS_home'])
plt.show()
# Out:
# The shape of the dataframe is:  (24677, 21)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### The IQR or Inter Quartile Range is a statistical measure used to measure the variability in a given data. In naive terms, it tells us inside what range the bulk of our data lies. It can be calculated by taking the difference between the third quartile and the first quartile within a dataset.
# ##### IQR = Q3 - Q1
# ###### Where, Q3 = the 75th percentile value (it is the middle value between the median and the largest value inside a dataset). Q1 = the 25th percentile value (it is the middle value between the median and the smallest value inside a dataset). Also, Q2 denotes the 50th percentile i.e., the median of a dataset.

# %%
# Removing the outliers
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')
def removeOutliers(game_df, col):
    Q1 = np.quantile(game_df[col], 0.25)
    Q3 = np.quantile(game_df[col], 0.75)
    
    IQR = Q3 - Q1
     
    print("IQR value for column %s is: %s" % (col, IQR))
    global outlier_free_list
    global filtered_data
     
lower_range = Q1 - 1.5 * IQR
upper_range = Q3 + 1.5 * IQR
outlier_free_list = [x for x in game_df[col] if (
    (x > lower_range) & (x < upper_range))]
filtered_data = game_df.loc[game_df[col].isin(outlier_free_list)]
 
 
for i in game_df.columns:
    removeOutliers(game_df, i)
 
#Assigning filtered data back to our original variable
game_df = filtered_data
print("Shape of data after outlier removal is: ", game_df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cd3041de7996> in <module>
#      15     global filtered_data
#      16
# ---> 17 lower_range = Q1 - 1.5 * IQR
#      18 upper_range = Q3 + 1.5 * IQR
#      19 outlier_free_list = [x for x in game_df[col] if (
#
# NameError: name 'Q1' is not defined

# %%
game_df.nunique()
# Out:
# GAME_DATE_EST        3957
# GAME_ID             24622
# GAME_STATUS_TEXT        1
# HOME_TEAM_ID           30
# VISITOR_TEAM_ID        30
# SEASON                 18
# TEAM_ID_home           30
# PTS_home               99
# FG_PCT_home           359
# FT_PCT_home           368
# FG3_PCT_home          387
# AST_home               42
# REB_home               55
# TEAM_ID_away           30
# PTS_away              104
# FG_PCT_away           350
# FT_PCT_away           352
# FG3_PCT_away          375
# AST_away               41
# REB_away               52
# HOME_TEAM_WINS          2
# dtype: int64

# %% [markdown]
# ## Stastistical Analysis

# %%
# %matplotlib inline
graph = game_df.hist(figsize = (12, 8))

# %%
#plotting histogram for Total points scored by home team
histogram =game_df.hist('PTS_home')

# %% [markdown]
# #### This shows that the graph of total points scored by the home team is normally distributed

# %% [markdown]
# ### Finding the Centeral Tendency - Mean,Meadian,Mode
# ###### Central tendency is a descriptive summary of a dataset through a single value that reflects the center of the data distribution.It lets us know what is normal or 'average' for a set of data. It also condenses the data set down to one representative value, which is useful when you are working with large amounts of data.

# %%
import numpy as np 
import pandas as pd 
pd.DataFrame([game_df.PTS_home.mean(),
              game_df.PTS_home.median(), 
              game_df.PTS_home.std(), 
              game_df.PTS_home.var()], 
             index=['Mean', 'Median','Std. dev', 'Variance'])
# Out:
#                    0
# Mean      102.766621
# Median    102.000000
# Std. dev   13.112642
# Variance  171.941382

# %% [markdown]
# #### Graph for Sample statistics

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns


#Plotting the graph for the central tendency , this helps us understand the average of the data and how it is ditributed
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=game_df['PTS_home'].mean()
median=game_df['PTS_home'].median()
mode=game_df['PTS_home'].mode().values[0]

sns.boxplot(data=game_df, x="PTS_home", ax=ax_box)
ax_box.axvline(mean, color='b', linestyle='--')
ax_box.axvline(median, color='r', linestyle='-')
ax_box.axvline(mode, color='g', linestyle='-')

sns.histplot(data=game_df, x="PTS_home", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='b', linestyle='--', label="Mean")
ax_hist.axvline(median, color='m', linestyle='-', label="Median")
ax_hist.axvline(mode, color='k', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %% [markdown]
# ##### This graph shows that the mean,median and mode are amost the same and the data is  normally distributed

# %% [markdown]
# ### Random Sampling
# ###### Definition: Random sampling is a part of the sampling technique in which each sample has an equal probability of being chosen. A sample chosen randomly is meant to be an unbiased representation of the total population. ... An unbiased random sample is important for drawing conclusions
# ##### Simple random sampling is a method used to cull a smaller sample size from a larger population and use it to research and make generalizations about the larger group.

# %%
#Creating duplicate copies of the df to perform random sampling
duplicate_game_df= game_df.copy()

# %% [markdown]
# ###### Why duplicate data ? Oversampling and undersampling in data analysis are techniques used to adjust the class distribution of a data set (i.e. the ratio between the different classes/categories represented). These terms are used both in statistical sampling, survey design methodology and in machine learning.

# %%
#Graph to show the data distribution of the raw dataset
import matplotlib 
import seaborn as sns 
import scipy 
from matplotlib import pyplot as plt
sns.set() 

x = duplicate_game_df['PTS_home']
result = plt.hist(x, bins=20, color='m', edgecolor='k', alpha=0.9)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=3)

min_ylim, max_ylim = plt.ylim()
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Total Points scored by the home team in game")

plt.show()

# %% [markdown]
# ###### The graph shows that random samples are sucessfully duplicated and they are still noramally distributed

# %%
# Creating multiple sample datasets to perform random sampling 

df1= duplicate_game_df['PTS_home'].sample(frac=0.3, replace=True, random_state=10)
df2= duplicate_game_df['PTS_home'].sample(frac=0.3, replace=True, random_state=100)
df3= duplicate_game_df['PTS_home'].sample(frac=0.3, replace=True, random_state=1000)
df4= duplicate_game_df['PTS_home'].sample(frac=0.3, replace=True, random_state=10000)
df5= duplicate_game_df['PTS_home'].sample(frac=0.3, replace=True, random_state=100000)
df6= duplicate_game_df['PTS_home'].sample(frac=0.3, replace=True, random_state=1000000)

# %% [markdown]
# ### Visualizing data keeping Sample size constant and varing the Sample space

# %%
#Visualising the data distribution - Here firstly we are going to keep the sample size constant and vary the sample space and plt a graph to check if there is any difference in the ditribution

#importing the required libraries for distribution
import matplotlib 
import seaborn as sns 
plt.figure(figsize=(18,12))


min_ylim, max_ylim = plt.ylim()

#df1 : Sample size-30,Sample space-10
plt.subplot(2,3,1) 
result = plt.hist(df1, bins=20, color='b', edgecolor='g', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='g', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-30,Sample space-10")

#df2 : Sample size-30,Sample space-100
plt.subplot(2,3,2)
result = plt.hist(df2, bins=20, color='y', edgecolor='r', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='r', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-30,Sample space-100")

#df3 : Sample size-30,Sample space-1000
plt.subplot(2,3,3)
result = plt.hist(df3, bins=20, color='m', edgecolor='k', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='k', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-30,Sample space-1000")

#df4 : Sample size-30,Sample space-10000
plt.subplot(2,3,4)
result = plt.hist(df4, bins=20, color='b', edgecolor='g', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='g', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-30,Sample space-10000")

#df5: Sample size-30,Sample space-100000
plt.subplot(2,3,5)
result = plt.hist(df5, bins=20, color='y', edgecolor='r', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='r', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-30,Sample space-100000")

#df6 : Sample size-30,Sample space-1000000
plt.subplot(2,3,6)
result = plt.hist(df6, bins=20, color='m', edgecolor='k', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='k', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-30,Sample space-1000000")
# Out:
# Text(0.5, 1.0, 'Sample size-30,Sample space-1000000')

# %% [markdown]
# ###### The result graphs are normally distributed, although we are keeping the sample size constant to 30 and varying the sample space there narrow difference among them.

# %% [markdown]
# ### Visualizing data keeping Sample space constant and varing the Sample size

# %%
#In this scenario we are going to resverse and keep the sample space constant an chnage the sample size and plt a graph accordingly 
import numpy as np 
import pandas as pd 

#Varying the ss from 50-1000000 and finding mean for them respectively 
rs_100 = pd.DataFrame({'Mean_PTS':[duplicate_game_df.sample(n=100, replace=True)['PTS_home'].mean() for i in range(10000)]})
rs_30 = pd.DataFrame({'Mean_PTS':[duplicate_game_df.sample(n=50, replace=True)['PTS_home'].mean() for i in range(10000)]})
rs_1000 = pd.DataFrame({'Mean_PTS':[duplicate_game_df.sample(n=1000, replace=True)['PTS_home'].mean() for i in range(10000)]})
rs_10000 = pd.DataFrame({'Mean_PTS':[duplicate_game_df.sample(n=10000, replace=True)['PTS_home'].mean() for i in range(10000)]})
rs_100000 = pd.DataFrame({'Mean_PTS':[duplicate_game_df.sample(n=100000, replace=True)['PTS_home'].mean() for i in range(10000)]})
rs_1000000 = pd.DataFrame({'Mean_PTS':[duplicate_game_df.sample(n=1000000, replace=True)['PTS_home'].mean() for i in range(10000)]})


ss_100 = rs_100.Mean_PTS
ss_30 = rs_30.Mean_PTS
ss_1000 = rs_1000.Mean_PTS
ss_10000 = rs_10000.Mean_PTS
ss_100000 = rs_100000.Mean_PTS
ss_1000000 = rs_1000000.Mean_PTS

# %%
#Visualizing the above mean of the random samples 


plt.figure(figsize=(16,20))

#Setting the plotting criteria 
min_ylim, max_ylim = plt.ylim()

#Ploting graph for sample size 100 and sc = 10000
plt.subplot(3,3,1) 
result = plt.hist(ss_100, bins=20, color='m', edgecolor='k', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='k', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-100")

#Ploting graph for sample size 50 and sc = 10000
plt.subplot(3,3,2) 
result = plt.hist(ss_30, bins=20, color='b', edgecolor='g', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='g', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-30")

#Ploting graph for sample size 1000 and sc = 10000
plt.subplot(3,3,3) 
result = plt.hist(ss_1000, bins=20, color='y', edgecolor='r', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='r', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-1000")

#Ploting graph for sample size 10000 and sc = 10000
plt.subplot(3,3,4) 
result = plt.hist(ss_10000, bins=20, color='m', edgecolor='k', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='k', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-10000")

#Ploting graph for sample size 100000 and sc = 10000
plt.subplot(3,3,5) 
result = plt.hist(ss_100000, bins=20, color='b', edgecolor='g', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='g', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-100000")

#Ploting graph for sample size 1000000 and sc = 10000
plt.subplot(3,3,6) 
result = plt.hist(ss_1000000, bins=20, color='y', edgecolor='r', alpha=0.9)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='k', linestyle='dashed', linewidth=3)
plt.ylabel('Count')
plt.xlabel('PTS_home')
plt.title("Sample size-1000000")


plt.show()

# %% [markdown]
# #### This graph shows that with the varying sample size the graph has changed to exponential graph

# %%
#Here we will be calculating and plotting the estimated mean
from scipy.stats import norm 


plt.figure(figsize=(18,20))

plt.subplot(3,3,1) 
mu = np.mean(ss_100)
std = np.std(ss_100)
# Plot the histogram.
plt.hist(ss_100, density=True, bins=20, color='b', edgecolor='g', alpha=0.9)
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
#formula for finding the pdf - mean,median and std deviation 
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=3.5)
title = "N=100: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='b', linestyle='dashed', linewidth=3)
plt.ylabel('PDF with const sc and varying ss')
plt.xlabel('PTS_home')


plt.subplot(3,3,2) 
mu = np.mean(ss_30)
std = np.std(ss_30)
# Plot the histogram.
plt.hist(ss_30, density=True, bins=20, color='m', edgecolor='k', alpha=0.9)
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=3.5)
title = "N=30: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='k', linestyle='dashed', linewidth=3)
plt.ylabel('PDF with const sc and varying ss')
plt.xlabel('PTS_home')

plt.subplot(3,3,3)
mu = np.mean(ss_1000)
std = np.std(ss_1000)
# Plot the histogram.
plt.hist(ss_1000, density=True, bins=20, color='b', edgecolor='g', alpha=0.9)
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=3.5)
title = "N=1000: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='g', linestyle='dashed', linewidth=3)
plt.ylabel('PDF with const sc and varying ss')
plt.xlabel('PTS_home')

plt.subplot(3,3,4) 
mu = np.mean(ss_10000)
std = np.std(ss_10000)
# Plot the histogram.
plt.hist(ss_10000, density=True, bins=20, color='m', edgecolor='k', alpha=0.9)
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=3.5)
title = "N=10000: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='k', linestyle='dashed', linewidth=3)
plt.ylabel('PDF with const sc and varying ss')
plt.xlabel('PTS_home')


plt.subplot(3,3,5) 
mu = np.mean(ss_100000)
std = np.std(ss_100000)
# Plot the histogram.
plt.hist(ss_100000, density=True, bins=20, color='b', edgecolor='g', alpha=0.9)
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=3.5)
title = "N=100000: mu = %.2f,  std =  %.2f" % (mu, std)
plt.title(title)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='g', linestyle='dashed', linewidth=3)
plt.ylabel('PDF with const sc and varying ss')
plt.xlabel('PTS_home')


plt.subplot(3,3,6) 
mu = np.mean(ss_1000000)
std = np.std(ss_1000000)
# Plot the histogram.
plt.hist(ss_1000000, density=True, bins=20, color='m', edgecolor='k', alpha=0.9)
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=3.5)
title = "N=1000000: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.axvline(duplicate_game_df['PTS_home'].mean(), color='k', linestyle='dashed', linewidth=3)
plt.ylabel('PDF with const sc and varying ss')
plt.xlabel('PTS_home')



plt.show()

# %% [markdown]
# #### The above graphs are therefore similar Centeral Tendency graph we intially plotted. These graphs are also normally distributed which indicate that the estimated mean of all the ramdom sampling is similar to the mean of the PTS_home coulmn of the dataset( drawing conclutions based on the graphs)

# %% [markdown]
# ## Report :
# ###### --> Observations:
# ##### 1. The results show us that a:
# #### Increasing the sample size decreases the standard deviation of the distribution of the sample means.The normal curve becomes narrower. As we can see that all the graphs are normally distributed.
# #### --> The purpose of this data visualization is to understand the random sampling  and how it can vary depending on the scenario where we change the sample size and sample count, keeping either one of them constant.
# #### ---> With respect to the polling example If the population size is small or the size of the individual samples and their number are relatively small, random sampling provides the best results since all candidates have an equal chance of being chosen.
# #### ---> It was unusual to find that the graphs come out similar to each other even though they have  large difference in thier inputs provided for finding the mean.
# #### In future we can 1.  perform the random sampling for the Opponent team and compare it with that of the home team.       2. We can predict the win of the team based on their scoring pattern
